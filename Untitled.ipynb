# %%
import pandas as pd

df = pd.read_csv('customer_shopping_behevior.cvs')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2
#       3 df = pd.read_csv('customer_shopping_behevior.cvs')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.head()
